# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: false
# check_all_cell: false
# export_cell: false
# python_version: 3.11
# requirements: requirements.txt
# generate:
#     debug: true
#     show_stdout: true
#     show_hidden: true

# %% [markdown]
# ## Ignore ##
# Follow this rubric to grade this exercise.
#
# 1) If you deduct points, comment the reason in the Gradescope submission.
#
# 2) If giving autograder points back, indicate why in the Gradescope submission
#
# 3) 1 point is for best coding practices. Make sure they are commenting, printing their outputs, not hardcoding answers, and not copy/pasting code from outside sources on things we hvae not learned about in class yet.

# %% [markdown]
# # In-class coding exercise #6
# Objective: In this exercise you will practice using xarray, making 2D plots, and converting between xarray and pandas.
#
# ## Introduction to group coding exercises
# Today you’ll work on this exercise in new groups of 3-4, submitting a single notebook file at the end of the class period. Decide amongst yourselves which member will upload the completed notebook to Gradescope this week. Make sure that everyone takes a turn being the “Uploader”. _You cannot upload the final code two weeks in a row._
#
# Designate a different group member to be the "Reporter". The Reporter will be in charge of participating in the group discussion at the end of the class session.
#
# ### Workflow
# Each question will be timed to ensure that everyone gets to work on at least a part of every question. Group activities are not graded by completeness or correctness, but by effort. We will be breaking down each question in the following order:
# 1. Independent work
# 2. Group work and discussion on coding question
# 3. Group work and discussion on reflection questions
#
# You are welcome and encouraged to communicate with other groups and the teaching team when you feel stuck on a problem.
#
# As a reminder, we will be grading based best practices in coding. These include:
# 1) Variables are used to store objects
#
# 2) Make sure that your variable names are meaningful
#
# 3) Format your code consistently
#
# 4) Add comments to document your intention, as well as (less commonly) tricky implementation
#
# 5) Documenting help from outside sources, such as from other groups or online documentation.
#
# 6) Final notebook fully runs from start to finish. A good way to check this is restarting the kernel and fully running through all the cells to check for any errors.
#
# ### Storing your answers
# In the code cells where you will write your answers, there will be comments denoting:
#
# "**# your code**"
#
# and
#
# "**# answer variables**"
#
# You may store any intermediary variables in the **your code** section. If you do not have any intermediary, you can also store your answer directly in the answer variables.
#
# ### Required Plot Elements for Figures
# This assignments requires you to create and design figures using `matplotlib`. To practice good plotting practices, each figure will require the following to receive full points:
# 1) Concise, descriptive title for each figure/subplot
# 2) Axis labels with units (when possible)
# 3) Appropriate axis limits (minimum and maximum)
# 4) Appropriate tick resolution
# 5) Legend when using different datasets
# 6) Appropriate font size (a good range is 12-15)

# %% [markdown]
# ## Note here **and in the Gradescope submission** each of your group members:
# 1.
# 2.
# 3.

# %% [raw]
# # BEGIN QUESTION
# name: Question 1
# manual: true
# check_cell: false

# %% [markdown]
# # Question 1: Practice reading files with `xarray`: World Ocean Atlas global ocean temperatures
# ### <font color='red'><i>Max time for all Q1 parts: 45 minutes</i></font>

# %% [markdown]
# 1. Load the WOA18 netCDF URL into xarray using `xr.open_dataset()` using the url string in the cell below. Set the named argument for "decode_times=False". This will keep the dates as a string instead of converting them to datetimes.
# 2. Display the data.
# 3. Using just the interactive display, answer the following questions with your group:
#
# > 1. How many data variables are there?
# > 2. The variable abbreviations aren't very informative. Using the page icon, find out what at least 3 variables represent and list them.
# > 3. What is the time range of the data?
# > 4. What is the latitude and longitude resolution (spacing) of the data? Note that we call this the "grid spacing" or "resolution" of the data.
#
# Subset your xarray dataset values using xarray or numpy functions to answer the following extra credit questions. Type your answers in the markdown cell below Part 3. Answer the questions in each part in comments below or above your code in the solution cell.
# > 5. What are the dimensions of the dataset? Type this in a new variable to store and print it. Take a look at your coordinates, specifically depth. Use a `numpy` function to calculate the deepest measurement of depth.
# > 6. Let's take a look at how much sampling was done at the equator. Subset your dataset's "lat" coordinates to 0. Do you see any measurements?
# - If not, try experimenting with the "method" argument to see if you can see other measurements nearby. How many measurements do you see now?
# - What is the range of values for lat (latitude) you see shown when you use "method"?
#
# > 7. Create a plot of temperature at the equator using the `plot()` function on your subsetted equatorial dataset. Don't forget to reverse the y-axis for depth!
# > 8. How does temperature vary at different latitudes? Now, try subsetting a dataset to -60 with the "lat" coordinates. Plot your figure and compare it against your equatorial plot.

# %% [markdown]
# ## IGNORE ##
# ### Answers to part 2:
# - How many data variables are there?
#   - 12
#
# - The variable abbreviations aren't very informative. Using the attributes button (page icon), find out what at least 3 variables represent and list them.
#     - Any 3 variables included are acceptable (ex:)
#
# - What is the time range of the data?
#   - months since 1955-01-01
#
# - What is the latitude and longitude resolution (spacing) of the data? Note that we call this the "grid spacing" or "resolution" of the data.
#   - one degree

# %%
# Starter code cell, DO NOT CHANGE!
url="https://www.ncei.noaa.gov/thredds-ocean/dodsC/ncei/woa/temperature/decav/1.00/woa18_decav_t00_01.nc"

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
ds =xr.open_dataset(url, decode_times=False) 
display(ds)
# END SOLUTION
""" # BEGIN PROMPT
# what packages do you need to import

# your code

# display your dataset

"""; # END PROMPT
# Out:
# <xarray.Dataset> Size: 238MB
# Dimensions:             (lat: 180, nbounds: 2, lon: 360, depth: 102, time: 1)
# Coordinates:
#   * lat                 (lat) float32 720B -89.5 -88.5 -87.5 ... 87.5 88.5 89.5
#   * lon                 (lon) float32 1kB -179.5 -178.5 -177.5 ... 178.5 179.5
#   * depth               (depth) float32 408B 0.0 5.0 10.0 ... 5.4e+03 5.5e+03
#   * time                (time) float32 4B 4.326e+03
# Dimensions without coordinates: nbounds
# Data variables:
#     crs                 int32 4B ...
#     lat_bnds            (lat, nbounds) float32 1kB ...
#     lon_bnds            (lon, nbounds) float32 3kB ...
#     depth_bnds          (depth, nbounds) float32 816B ...
#     climatology_bounds  (time, nbounds) float32 8B ...
#     t_an                (time, depth, lat, lon) float32 26MB ...
#     t_mn                (time, depth, lat, lon) float32 26MB ...
#     t_dd                (time, depth, lat, lon) float64 53MB ...
#     t_sd                (time, depth, lat, lon) float32 26MB ...
#     t_se                (time, depth, lat, lon) float32 26MB ...
#     t_oa                (time, depth, lat, lon) float32 26MB ...
#     t_gp                (time, depth, lat, lon) float64 53MB ...
# Attributes: (12/49)
#     Conventions:                     CF-1.6, ACDD-1.3
#     title:                           World Ocean Atlas 2018 : sea_water_tempe...
#     summary:                         Climatological mean temperature for the ...
#     references:                      Locarnini, R. A., A. V. Mishonov, O. K. ...
#     institution:                     National Centers for Environmental Infor...
#     comment:                         global climatology as part of the World ...
#     ...                              ...
#     publisher_email:                 NCEI.info@noaa.gov
#     nodc_template_version:           NODC_NetCDF_Grid_Template_v2.0
#     license:                         These data are openly available to the p...
#     metadata_link:                   https://www.nodc.noaa.gov/OC5/woa18/
#     date_created:                    2019-07-28
#     date_modified:                   2019-07-28

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# ### Type your answer to part 3 here:
# 1)
#
# 2)
#
# 3)
#
# 4)

# %%
# your code

# your plots 

# BEGIN SOLUTION NO PROMPT
# part 5
ds_dims = ds.dims
print('Dataset dimensions:', ds_dims)
print('Deepest measurement:',np.max(ds.depth.values), 'm')
# part 6
print('There are',len(ds.sel(lat=0, method="nearest")), 'measurements when we use nearest')
# the only latitude values chosen are 0.5
# part 7
low_lat = ds['t_an'].sel(lat=0, method="nearest").isel(time = 0) # We use .isel to get rid of excess time dimension

fig = plt.figure(figsize = (10, 6))
ax = fig.add_subplot()

mesh1 = ax.pcolormesh(low_lat['lon'], low_lat['depth'], low_lat, cmap = 'plasma')
cb1 = fig.colorbar(mesh1, ax = ax) # Assigning a colorbar to our plot! (Same idea of giving it a variable to reference later)
cb1.set_label('Temperature (°C)', fontsize = 14) # Using our colorbar variable to make a label
cb1.ax.tick_params(labelsize = 14)
ax.invert_yaxis()
ax.set_xlabel('Longitude (°E)')
ax.set_ylabel('Depth (m)')
ax.set_title('Equatorial Slice of Ocean Temperatures')
plt.show(fig)


# part 8

high_lat = ds['t_an'].sel(lat=-60, method="nearest").isel(time = 0)
fig = plt.figure(figsize = (10, 6))

ax = fig.add_subplot()
mesh2 = ax.pcolormesh(high_lat['lon'], high_lat['depth'], high_lat, cmap = 'viridis')
cb2 = fig.colorbar(mesh2, ax = ax) # Assigning a colorbar to our plot! (Same idea of giving it a variable to reference later)
cb2.set_label('Temperature (°C)', fontsize = 14) # Using our colorbar variable to make a label
cb2.ax.tick_params(labelsize = 14)
ax.invert_yaxis()
ax.set_xlabel('Longitude (°E)')
ax.set_ylabel('Depth (m)')
ax.set_title('Slice of Ocean Temperatures at -60°S')
plt.show(fig)
# END SOLUTION
# Out:
# Dataset dimensions: FrozenMappingWarningOnValuesAccess({'lat': 180, 'nbounds': 2, 'lon': 360, 'depth': 102, 'time': 1})
# Deepest measurement: 5500.0 m
# There are 12 measurements when we use nearest

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# # Reflection questions (5 minutes)
# The purpose of the reflection is to inform us as instructors about students comfort level with course content. We use these answers to inform how we spend class time and design coursework in subsequent weeks. This question is graded for completeness, so please answer each question in the text box below. Be concise in your answers (max. 2 sentences).
#
# 1) What do you feel you excelled at in this exercise? Why?
#
# 2) What did you struggle with most in the exercise? Why?
#
# 3) Is there any section of the question that you did not complete? If so, briefly describe why and the section you spent the most time on.
#
# 4) Is there any topic you feel we need to revisit or review in class? Why?

# %% [markdown]
# 1)
#
# 2)
#
# 3)
#
# 4)

# %% [raw]
# # BEGIN QUESTION
# name: Question 2
# manual: true
# check_cell: false

# %% [markdown]
# # Q2: Primary Productivity from Station ALOHA
#
# Today, we will be analyzing primary production data from Station ALOHA.
#
# "Station ALOHA is the focal point of a range of oceanographic studies conducted over great temporal scale that intend to understand and explain the trends of the greater North Pacific Ocean." [Source](https://aco-ssds.soest.hawaii.edu/ALOHA/)
#
# Primary production is the measurement of carbon accumulated by photosynthesis. This term represents how much carbon is stored by unit volume and is calculated via the 14C-assimilation method. [Reference](https://hahana.soest.hawaii.edu/hot/protocols/protocols.html?Chapter=14)
#
# <img src = "https://i.ibb.co/Bf2Rt1b/station-aloha.png" width = 500>

# %% [markdown]
# ## Part 1 (20 minutes)
# Here, we will be getting familiar with our data. Download the `productivity_aloha.csv` file from the class website (or canvas) and upload it to your jupyter notebook.
#
# 1) Once you have your data loaded as `hot_df`, set the "time" column of the `hot_df` DataFrame to `datetime` using the `pandas.to_datetime()` function.
#
# 2) Sort `hot_df` by the "time" column using the `pandas.sort_values()` function.
#
# 3) Primary production measurements were taken at discrete (individual or separate) depths. To smooth some of the data, create a new column named "round_depth" that contains the rounded depth to **10 m**.
#
# 4) Store your updated `hot_df` dataframe as an xarray Dataset called `hot_xr`, using the `time`, `round_depth`, and `itype` variables to define the grid.
#
# 5) Display the new xarray dataset. How many variables does it have?

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT

import pandas as pd
import numpy as np
hot_df = pd.read_csv('productivity_aloha.csv')

display(hot_df)

# convert times to datetime using pd.to_datetime()
hot_df['time'] = pd.to_datetime(hot_df['time'], format = "%Y-%m-%dT%H:%M:%S")
# sort by time
hot_df.sort_values(by='time', inplace=True)
# bin values by every 20m
hot_df['round_depth'] = hot_df['depth'].round(-1)

hot_df = hot_df.set_index(["time", "round_depth", "itype"])

hot_xr = xr.Dataset.from_dataframe(hot_df)

display(hot_xr)

# END SOLUTION 
''' # BEGIN PROMPT
# Part 1 of Question 2

# Your code here:

'''; # END PROMPT
# Out:
#       Unnamed: 0                 time    lat  lon  depth  cruise  stime  \
# 0              0  1988-10-31T00:00:00  22.75 -158     24  HOT001    NaN
# 1              1  1988-10-31T00:00:00  22.75 -158     42  HOT001    NaN
# 2              2  1988-10-31T00:00:00  22.75 -158     68  HOT001    NaN
# 3              3  1988-10-31T00:00:00  22.75 -158    114  HOT001    NaN
# 4              4  1988-12-02T00:00:00  22.75 -158      0  HOT002    NaN
# ...          ...                  ...    ...  ...    ...     ...    ...
# 2584        2584  2022-09-01T00:00:00  22.75 -158     75  HOT339  443.0
# 2585        2585  2022-09-01T00:00:00  22.75 -158    100  HOT339  443.0
# 2586        2586  2022-09-01T00:00:00  22.75 -158    125  HOT339  443.0
# 2587        2587  2022-09-01T00:00:00  22.75 -158    150  HOT339  443.0
# 2588        2588  2022-09-01T00:00:00  22.75 -158    175  HOT339  443.0
#
#        etime  itype    chl  phaeo    l12   d12     bsal     pbact     hbact  \
# 0        NaN      0  0.129  0.077  12.21   NaN      NaN       NaN       NaN
# 1        NaN      0  0.192  0.051   2.47  0.07      NaN       NaN       NaN
# 2        NaN      0  0.285  0.303   2.58  0.06      NaN       NaN       NaN
# 3        NaN      0  0.326  0.044   0.72  0.16      NaN       NaN       NaN
# 4        NaN      0  0.202  0.000    NaN   NaN      NaN       NaN       NaN
# ...      ...    ...    ...    ...    ...   ...      ...       ...       ...
# 2584  1948.0      2  0.180  0.227    NaN   NaN  35.1478  200248.0  370916.0
# 2585  1948.0      2  0.208  0.578    NaN   NaN  35.1896  121881.0  251964.0
# 2586  1948.0      2  0.130  0.418    NaN   NaN  35.1410   24478.0  200659.0
# 2587  1948.0      2  0.076  0.310    NaN   NaN  35.0502   13892.0  161622.0
# 2588  1948.0      2  0.038  0.128    NaN   NaN  34.9628    4569.0  149048.0
#
#        sbact   ebact
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 2584  1742.0   910.0
# 2585   150.0  1067.0
# 2586     7.0   790.0
# 2587    10.0   409.0
# 2588     0.0   173.0
#
# [2589 rows x 18 columns]
# <xarray.Dataset> Size: 3MB
# Dimensions:      (time: 310, round_depth: 18, itype: 4)
# Coordinates:
#   * time         (time) datetime64[ns] 2kB 1988-10-31 1988-12-02 ... 2022-09-01
#   * round_depth  (round_depth) int64 144B 0 10 20 30 40 ... 130 140 150 160 180
#   * itype        (itype) int64 32B 0 1 2 3
# Data variables: (12/16)
#     Unnamed: 0   (time, round_depth, itype) float64 179kB nan nan ... nan
#     lat          (time, round_depth, itype) float64 179kB nan nan ... 22.75 nan
#     lon          (time, round_depth, itype) float64 179kB nan nan ... -158.0 nan
#     depth        (time, round_depth, itype) float64 179kB nan nan ... 175.0 nan
#     cruise       (time, round_depth, itype) object 179kB nan nan ... nan
#     stime        (time, round_depth, itype) float64 179kB nan nan ... 443.0 nan
#     ...           ...
#     d12          (time, round_depth, itype) float64 179kB nan nan ... nan nan
#     bsal         (time, round_depth, itype) float64 179kB nan nan ... 34.96 nan
#     pbact        (time, round_depth, itype) float64 179kB nan nan ... nan
#     hbact        (time, round_depth, itype) float64 179kB nan nan ... nan
#     sbact        (time, round_depth, itype) float64 179kB nan nan ... 0.0 nan
#     ebact        (time, round_depth, itype) float64 179kB nan nan ... 173.0 nan

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# # Reflection questions (5 minutes)
# The purpose of the reflection is to inform us as instructors about students comfort level with course content. We use these answers to inform how we spend class time and design coursework in subsequent weeks. This question is graded for completeness, so please answer each question in the text box below. Be concise in your answers (max. 2 sentences).
#
# 1) What do you feel you excelled at in this exercise? Why?
#
# 2) What did you struggle with most in the exercise? Why?
#
# 3) Is there any section of the question that you did not complete? If so, briefly describe why and the section you spent the most time on.
#
# 4) Is there any topic you feel we need to revisit or review in class? Why?

# %% [markdown]
# 1)
#
# 2)
#
# 3)
#
# 4)

# %% [raw]
# # BEGIN QUESTION
# name: completion
# points: 0
# check_cell: false

# %% [markdown]
# ## Check that your codes run without errors

# %% [markdown]
# #IGNORE
#
# #### Grading rubrics
#
# + Notebook that full runs get 1 point

# %% [markdown]
# Please check that your code runs without error when the notebook is executed from top to bottom. You may find the "Restart the kernel and run all cells" option (selectable using the `⏩` icon) useful.

# %% [raw]
# # BEGIN TESTS

# %%
# HIDDEN
assert True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
